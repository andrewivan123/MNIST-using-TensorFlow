# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
mnist = keras.datasets.mnist
(train_images,train_labels),(test_images,test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model = keras.Sequential([
      keras.layers.Flatten(input_shape=(28,28)),
      keras.layers.Dense(128,activation=tf.nn.relu),
      keras.layers.Dense(128,activation='relu'),
      keras.layers.Dense(10, activation=tf.nn.softmax)                     
],)

model.compile(
    optimizer = tf.train.AdamOptimizer(),
    loss='sparse_categorical_crossentropy',
    metrics = ['acc']
)

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
model.fit(train_images,train_labels,epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 84us/sample - loss: 1.7396 - acc: 0.8722
# Epoch 2/10
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.4039 - acc: 0.9205
# Epoch 3/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2802 - acc: 0.9363
# Epoch 4/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.1933 - acc: 0.9497
# Epoch 5/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.1576 - acc: 0.9567
# Epoch 6/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.1345 - acc: 0.9612
# Epoch 7/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.1222 - acc: 0.9668
# Epoch 8/10
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.1082 - acc: 0.9696
# Epoch 9/10
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.1084 - acc: 0.9704
# Epoch 10/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0958 - acc: 0.9730

# %%
model.evaluate(test_images,test_labels)
# Out:
# 10000/10000 [==============================] - 0s 37us/sample - loss: 0.1590 - acc: 0.9629
# [0.15897697429421243, 0.9629]

# %%
pred = model.predict(test_images)
for i,img in enumerate(test_images[10:20]):
  plt.imshow(img)
  plt.show()
  print("Category ",np.argmax(pred[10+i]))
# Out:
# Category  0
# Category  6
# Category  9
# Category  0
# Category  1
# Category  5
# Category  9
# Category  7
# Category  3
# Category  4
